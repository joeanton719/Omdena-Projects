# %%
from scipy.spatial import KDTree
from geopy.distance import geodesic
import pandas as pd

# %%
gh_df = (
    pd.read_csv("datasets/15_gh_info/geohash_traffic_density_pt_15clusters.csv", usecols=['GEOHASH', 'LATITUDE', 'LONGITUDE'])
)

# Reading Istanbul_landmarks dataset and converting to dictionary
# keys are landmark names and values are its coordinates
site_dict = (
    pd.read_csv("datasets/12_tr_ist_tourist_sites/ist_sites.csv")
    .drop('site_address', axis=1)
    .set_index('site_name')
    .T
    .to_dict()
)

site_dict
# Out:
# {'5 Temmuz Şehitler Köprüsü': {'latitude': 41.039928, 'longitude': 29.0402745},
#  '500. Yıl Vakfı Türk Musevileri Müzesi': {'latitude': 41.0267866,
#   'longitude': 28.9727283},
#  'Atik Valide Mosque': {'latitude': 41.0197939,
#   'longitude': 29.02915605209612},
#  'Basilica Cistern': {'latitude': 41.00840235, 'longitude': 28.97792248031497},
#  'Beylerbeyi Palace': {'latitude': 41.04268765,
#   'longitude': 29.04000176704749},
#  'Blue Mosque': {'latitude': 41.0054279, 'longitude': 28.97664968333884},
#  'Deniz Müzesi': {'latitude': 41.0410591, 'longitude': 29.005691266268045},
#  'Dolmabahçe Palace': {'latitude': 41.03896085,
#   'longitude': 28.99973803473693},
#  'Egyptian Spice Bazaar': {'latitude': 41.01641785,
#   'longitude': 28.970530846069572},
#  'Eyüp Sultan Mosque': {'latitude': 41.04801125,
#   'longitude': 28.93374562334459},
#  'Fatih Sultan Mehmet Köprüsü': {'latitude': 41.0913149,
#   'longitude': 29.06197573589518},
#  'Galata Bridge': {'latitude': 41.0182562, 'longitude': 28.9717712},
#  'Galata Mevlevihanesi Müzesi': {'latitude': 41.02801465,
#   'longitude': 28.97511564506988},
#  'Galata Tower': {'latitude': 41.0256406, 'longitude': 28.974213369331657},
#  'Gülhane Parkı': {'latitude': 41.0130256, 'longitude': 28.980901720442503},
#  'Hagia Sophia': {'latitude': 41.00850865, 'longitude': 28.980009932000005},
#  'Harbiye Askeri Müze': {'latitude': 41.0488755, 'longitude': 28.9882427},
#  'Kapalı Çarşı': {'latitude': 41.01098795, 'longitude': 28.968175837679787},
#  'Kariye Museum': {'latitude': 41.03119345, 'longitude': 28.938888304979635},
#  'Küçük Ayasofya': {'latitude': 41.0035865, 'longitude': 28.9723346},
#  'Meryem Ana Rum Ortodoks Kilisesi - Balat': {'latitude': 41.0296237,
#   'longitude': 28.9490475},
#  'Museum of Innocence': {'latitude': 41.0308716, 'longitude': 28.9797952},
#  'Museum of Turkish & Islamic Arts': {'latitude': 41.0062218,
#   'longitude': 28.9746583},
#  'Ortaköy Büyük Mecidiye Mosque': {'latitude': 41.0472944,
#   'longitude': 29.02682679965463},
#  'Pera Museum': {'latitude': 41.031803100000005,
#   'longitude': 28.97520378845893},
#  'Pierre Loti - Eyüp Merkez': {'latitude': 41.0537075,
#   'longitude': 28.9335372},
#  'Rahmi M Koç Museum': {'latitude': 41.04197345,
#   'longitude': 28.94856864859092},
#  'Rumeli Hisarı': {'latitude': 41.08491705, 'longitude': 29.05671252397693},
#  'Sabiha Gökçen International Airport': {'latitude': 40.89929455,
#   'longitude': 29.30755232959208},
#  'Süleymaniye Mosque': {'latitude': 41.0163008,
#   'longitude': 28.96397730996554},
#  'Taksim Square - Istanbul': {'latitude': 41.0380506, 'longitude': 28.985549},
#  'Topkapı Palace': {'latitude': 41.0129795, 'longitude': 28.98406594236272},
#  'Valens Su Kemeri': {'latitude': 41.01629325,
#   'longitude': 28.954968351578763},
#  'Yavuz Sultan Selim Bridge': {'latitude': 41.1997263,
#   'longitude': 29.1187922},
#  'Yıldız Park - Beşiktaş': {'latitude': 41.0478421, 'longitude': 29.0156916},
#  'Çamlıca Kulesi - Istanbul': {'latitude': 41.0163724,
#   'longitude': 29.0655409},
#  'Çırağan Palace': {'latitude': 41.04346705, 'longitude': 29.01531447935572},
#  'İBB 15 Temmuz Şehitler Ormanı ve Anıtı': {'latitude': 41.2075602,
#   'longitude': 29.0958613},
#  'İstanbul Arkeoloji Müzeleri': {'latitude': 41.01169865,
#   'longitude': 28.981322701685624},
#  'İstanbul Atatürk Havalimanı': {'latitude': 40.9774975,
#   'longitude': 28.82549354370232},
#  'İstanbul Havalimanı': {'latitude': 41.2753227,
#   'longitude': 28.73226923452166},
#  'İstanbul Modern Museum': {'latitude': 41.025911, 'longitude': 28.982812},
#  'İstiklal Caddesi': {'latitude': 41.0338927, 'longitude': 28.9782481}}

# %%
# Unique list of coordinates
coordinates = gh_df[['LATITUDE', 'LONGITUDE']].drop_duplicates().values
coordinates
# Out:
# array([[41.080627, 28.811646],
#        [40.987244, 29.108276],
#        [41.003723, 29.09729 ],
#        ...,
#        [40.976257, 29.229126],
#        [41.009216, 27.98767 ],
#        [41.020203, 27.998657]])

# %%
def find_nearest_coordinates(
        target_lat: float,
        target_lon: float,
        coordinates: list[list[float, float]]
        ) -> list[tuple[tuple[float, float], float]]:
    """
    Finds the nearest coordinates to a target latitude and longitude.

    Args:
        target_lat (float): The latitude of the target location.
        target_lon (float): The longitude of the target location.
        coordinates (List[Tuple[float, float]]): A list of tuples representing the coordinates to search from.

    Returns:
        List[Tuple[Tuple[float, float], float]]: A list of tuples containing the nearest coordinates and their distances in kilometers.
    """
    target_coords = (target_lat, target_lon)
    
    # Build a KDTree for efficient nearest neighbor search
    tree = KDTree(coordinates)

    # Calculate the search radius in degrees
    radius_deg = 1 / 111.0  # 1 km radius in degrees

    # Query the KDTree for indices of points within the search radius
    indices = tree.query_ball_point([(target_lat, target_lon)], radius_deg)

    # Calculate the distance between target coordinates and nearest coordinates
    nearest_coordinates = [(coordinates[i], geodesic(target_coords, coordinates[i]).km) for i in indices[0]]

    # Sort the nearest coordinates by distance
    nearest_coordinates.sort(key=lambda x: x[1])  # Sort by distance

    return nearest_coordinates

# %%
# %%time

hist_list = []
new_list = []

for site in site_dict:

    target_lat = site_dict[site]['latitude']
    target_lon = site_dict[site]['longitude']

    nearest_coords = find_nearest_coordinates(target_lat, target_lon, coordinates)

    print(f"Nearest Coordinates to {site}")
    print("---------------------------------------------------------")

    for i, (coords, distance) in enumerate(nearest_coords):

        gh = gh_df.loc[gh_df['LATITUDE'].eq(coords[0]) & gh_df['LONGITUDE'].eq(coords[1]), 'GEOHASH'].values[0]
        print(f"Nearest Coordinate {i+1}: {coords[0]}, {coords[1]}, Distance={distance:.2f} km, GEOHASH: {gh}")

        # Creating two dataframe which will later be merged rows wise for visualization purpose.
        hist_list.append({
            "type" : "landmark",
            "name" : site,
            "latitude" : target_lat,
            "longitude" : target_lon,
            "nearest" : site
        })

        new_list.append({
            "type" : "geohash",
            "name" : gh,
            "latitude" : coords[0],
            "longitude" : coords[1],
            "nearest" : site
        })

    print()
# Out:
# Nearest Coordinates to 5 Temmuz Şehitler Köprüsü
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 29.042358, Distance=0.30 km, GEOHASH: sxk9kz
# Nearest Coordinate 2: 41.036682, 29.042358, Distance=0.40 km, GEOHASH: sxk9ky
# Nearest Coordinate 3: 41.03119, 29.042358, Distance=0.99 km, GEOHASH: sxk9kv
#
# Nearest Coordinates to 500. Yıl Vakfı Türk Musevileri Müzesi
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.025696, 28.97644, Distance=0.33 km, GEOHASH: sxk97k
# Nearest Coordinate 2: 41.03119, 28.97644, Distance=0.58 km, GEOHASH: sxk97m
# Nearest Coordinate 3: 41.025696, 28.965454, Distance=0.62 km, GEOHASH: sxk97h
# Nearest Coordinate 4: 41.03119, 28.965454, Distance=0.78 km, GEOHASH: sxk97j
# Nearest Coordinate 5: 41.020203, 28.97644, Distance=0.79 km, GEOHASH: sxk977
#
# Nearest Coordinates to Atik Valide Mosque
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.020203, 29.031372, Distance=0.19 km, GEOHASH: sxk9ke
# Nearest Coordinate 2: 41.01471, 29.031372, Distance=0.59 km, GEOHASH: sxk9kd
# Nearest Coordinate 3: 41.025696, 29.031372, Distance=0.68 km, GEOHASH: sxk9ks
# Nearest Coordinate 4: 41.020203, 29.020386, Distance=0.74 km, GEOHASH: sxk9k7
#
# Nearest Coordinates to Basilica Cistern
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.003723, 28.97644, Distance=0.53 km, GEOHASH: sxk972
# Nearest Coordinate 2: 41.01471, 28.97644, Distance=0.71 km, GEOHASH: sxk976
#
# Nearest Coordinates to Beylerbeyi Palace
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 29.042358, Distance=0.21 km, GEOHASH: sxk9kz
# Nearest Coordinate 2: 41.036682, 29.042358, Distance=0.70 km, GEOHASH: sxk9ky
# Nearest Coordinate 3: 41.042175, 29.031372, Distance=0.73 km, GEOHASH: sxk9kx
#
# Nearest Coordinates to Blue Mosque
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.003723, 28.97644, Distance=0.19 km, GEOHASH: sxk972
#
# Nearest Coordinates to Deniz Müzesi
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 29.0094, Distance=0.34 km, GEOHASH: sxk9kp
# Nearest Coordinate 2: 41.042175, 28.998413, Distance=0.62 km, GEOHASH: sxk97z
# Nearest Coordinate 3: 41.036682, 28.998413, Distance=0.78 km, GEOHASH: sxk97y
# Nearest Coordinate 4: 41.04767, 29.0094, Distance=0.80 km, GEOHASH: sxk9s0
#
# Nearest Coordinates to Dolmabahçe Palace
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.036682, 28.998413, Distance=0.28 km, GEOHASH: sxk97y
# Nearest Coordinate 2: 41.042175, 28.998413, Distance=0.37 km, GEOHASH: sxk97z
# Nearest Coordinate 3: 41.04767, 28.998413, Distance=0.97 km, GEOHASH: sxk9eb
#
# Nearest Coordinates to Egyptian Spice Bazaar
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 28.97644, Distance=0.53 km, GEOHASH: sxk976
# Nearest Coordinate 2: 41.020203, 28.965454, Distance=0.60 km, GEOHASH: sxk975
# Nearest Coordinate 3: 41.020203, 28.97644, Distance=0.65 km, GEOHASH: sxk977
# Nearest Coordinate 4: 41.009216, 28.965454, Distance=0.91 km, GEOHASH: sxk971
#
# Nearest Coordinates to Eyüp Sultan Mosque
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.04767, 28.932495, Distance=0.11 km, GEOHASH: sxk9d2
# Nearest Coordinate 2: 41.05316, 28.932495, Distance=0.58 km, GEOHASH: sxk9d3
# Nearest Coordinate 3: 41.042175, 28.932495, Distance=0.66 km, GEOHASH: sxk96r
#
# Nearest Coordinates to Fatih Sultan Mehmet Köprüsü
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.091614, 29.064331, Distance=0.20 km, GEOHASH: sxk9v2
# Nearest Coordinate 2: 41.091614, 29.053345, Distance=0.73 km, GEOHASH: sxk9v0
#
# Nearest Coordinates to Galata Bridge
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.020203, 28.97644, Distance=0.45 km, GEOHASH: sxk977
# Nearest Coordinate 2: 41.01471, 28.97644, Distance=0.56 km, GEOHASH: sxk976
# Nearest Coordinate 3: 41.020203, 28.965454, Distance=0.57 km, GEOHASH: sxk975
# Nearest Coordinate 4: 41.025696, 28.97644, Distance=0.91 km, GEOHASH: sxk97k
#
# Nearest Coordinates to Galata Mevlevihanesi Müzesi
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.025696, 28.97644, Distance=0.28 km, GEOHASH: sxk97k
# Nearest Coordinate 2: 41.03119, 28.97644, Distance=0.37 km, GEOHASH: sxk97m
# Nearest Coordinate 3: 41.020203, 28.97644, Distance=0.87 km, GEOHASH: sxk977
# Nearest Coordinate 4: 41.036682, 28.97644, Distance=0.97 km, GEOHASH: sxk97q
#
# Nearest Coordinates to Galata Tower
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.025696, 28.97644, Distance=0.19 km, GEOHASH: sxk97k
# Nearest Coordinate 2: 41.020203, 28.97644, Distance=0.63 km, GEOHASH: sxk977
# Nearest Coordinate 3: 41.03119, 28.97644, Distance=0.64 km, GEOHASH: sxk97m
# Nearest Coordinate 4: 41.025696, 28.965454, Distance=0.74 km, GEOHASH: sxk97h
#
# Nearest Coordinates to Gülhane Parkı
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 28.97644, Distance=0.42 km, GEOHASH: sxk976
# Nearest Coordinate 2: 41.01471, 28.987427, Distance=0.58 km, GEOHASH: sxk97d
# Nearest Coordinate 3: 41.009216, 28.987427, Distance=0.69 km, GEOHASH: sxk979
# Nearest Coordinate 4: 41.020203, 28.97644, Distance=0.88 km, GEOHASH: sxk977
#
# Nearest Coordinates to Hagia Sophia
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.003723, 28.97644, Distance=0.61 km, GEOHASH: sxk972
# Nearest Coordinate 2: 41.009216, 28.987427, Distance=0.63 km, GEOHASH: sxk979
# Nearest Coordinate 3: 41.01471, 28.97644, Distance=0.75 km, GEOHASH: sxk976
# Nearest Coordinate 4: 41.003723, 28.987427, Distance=0.82 km, GEOHASH: sxk978
#
# Nearest Coordinates to Harbiye Askeri Müze
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.04767, 28.987427, Distance=0.15 km, GEOHASH: sxk9e8
# Nearest Coordinate 2: 41.05316, 28.987427, Distance=0.48 km, GEOHASH: sxk9e9
# Nearest Coordinate 3: 41.042175, 28.987427, Distance=0.75 km, GEOHASH: sxk97x
#
# Nearest Coordinates to Kapalı Çarşı
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.009216, 28.965454, Distance=0.30 km, GEOHASH: sxk971
# Nearest Coordinate 2: 41.003723, 28.965454, Distance=0.84 km, GEOHASH: sxk970
#
# Nearest Coordinates to Kariye Museum
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.943481, Distance=0.39 km, GEOHASH: sxk96t
# Nearest Coordinate 2: 41.03119, 28.932495, Distance=0.54 km, GEOHASH: sxk96m
# Nearest Coordinate 3: 41.036682, 28.943481, Distance=0.72 km, GEOHASH: sxk96w
# Nearest Coordinate 4: 41.025696, 28.943481, Distance=0.72 km, GEOHASH: sxk96s
# Nearest Coordinate 5: 41.036682, 28.932495, Distance=0.81 km, GEOHASH: sxk96q
# Nearest Coordinate 6: 41.025696, 28.932495, Distance=0.81 km, GEOHASH: sxk96k
#
# Nearest Coordinates to Küçük Ayasofya
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.003723, 28.97644, Distance=0.35 km, GEOHASH: sxk972
# Nearest Coordinate 2: 41.003723, 28.965454, Distance=0.58 km, GEOHASH: sxk970
# Nearest Coordinate 3: 41.009216, 28.965454, Distance=0.85 km, GEOHASH: sxk971
#
# Nearest Coordinates to Meryem Ana Rum Ortodoks Kilisesi - Balat
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.954468, Distance=0.49 km, GEOHASH: sxk96v
# Nearest Coordinate 2: 41.03119, 28.943481, Distance=0.50 km, GEOHASH: sxk96t
# Nearest Coordinate 3: 41.025696, 28.954468, Distance=0.63 km, GEOHASH: sxk96u
# Nearest Coordinate 4: 41.025696, 28.943481, Distance=0.64 km, GEOHASH: sxk96s
# Nearest Coordinate 5: 41.036682, 28.954468, Distance=0.91 km, GEOHASH: sxk96y
# Nearest Coordinate 6: 41.036682, 28.943481, Distance=0.91 km, GEOHASH: sxk96w
#
# Nearest Coordinates to Museum of Innocence
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.97644, Distance=0.28 km, GEOHASH: sxk97m
# Nearest Coordinate 2: 41.025696, 28.97644, Distance=0.64 km, GEOHASH: sxk97k
# Nearest Coordinate 3: 41.03119, 28.987427, Distance=0.64 km, GEOHASH: sxk97t
# Nearest Coordinate 4: 41.036682, 28.97644, Distance=0.70 km, GEOHASH: sxk97q
#
# Nearest Coordinates to Museum of Turkish & Islamic Arts
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.003723, 28.97644, Distance=0.32 km, GEOHASH: sxk972
# Nearest Coordinate 2: 41.01471, 28.97644, Distance=0.95 km, GEOHASH: sxk976
#
# Nearest Coordinates to Ortaköy Büyük Mecidiye Mosque
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.04767, 29.031372, Distance=0.38 km, GEOHASH: sxk9s8
# Nearest Coordinate 2: 41.04767, 29.020386, Distance=0.54 km, GEOHASH: sxk9s2
# Nearest Coordinate 3: 41.042175, 29.031372, Distance=0.69 km, GEOHASH: sxk9kx
# Nearest Coordinate 4: 41.05316, 29.031372, Distance=0.76 km, GEOHASH: sxk9s9
# Nearest Coordinate 5: 41.05316, 29.020386, Distance=0.85 km, GEOHASH: sxk9s3
#
# Nearest Coordinates to Pera Museum
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.97644, Distance=0.12 km, GEOHASH: sxk97m
# Nearest Coordinate 2: 41.036682, 28.97644, Distance=0.55 km, GEOHASH: sxk97q
# Nearest Coordinate 3: 41.025696, 28.97644, Distance=0.69 km, GEOHASH: sxk97k
#
# Nearest Coordinates to Pierre Loti - Eyüp Merkez
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.05316, 28.932495, Distance=0.11 km, GEOHASH: sxk9d3
# Nearest Coordinate 2: 41.058655, 28.932495, Distance=0.56 km, GEOHASH: sxk9d6
# Nearest Coordinate 3: 41.04767, 28.932495, Distance=0.68 km, GEOHASH: sxk9d2
#
# Nearest Coordinates to Rahmi M Koç Museum
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 28.943481, Distance=0.43 km, GEOHASH: sxk96x
# Nearest Coordinate 2: 41.042175, 28.954468, Distance=0.50 km, GEOHASH: sxk96z
# Nearest Coordinate 3: 41.036682, 28.943481, Distance=0.73 km, GEOHASH: sxk96w
# Nearest Coordinate 4: 41.04767, 28.943481, Distance=0.76 km, GEOHASH: sxk9d8
# Nearest Coordinate 5: 41.036682, 28.954468, Distance=0.77 km, GEOHASH: sxk96y
# Nearest Coordinate 6: 41.04767, 28.954468, Distance=0.80 km, GEOHASH: sxk9db
#
# Nearest Coordinates to Rumeli Hisarı
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.091614, 29.053345, Distance=0.80 km, GEOHASH: sxk9v0
# Nearest Coordinate 2: 41.080627, 29.064331, Distance=0.80 km, GEOHASH: sxk9tq
#
# Nearest Coordinates to Sabiha Gökçen International Airport
# ---------------------------------------------------------
#
# Nearest Coordinates to Süleymaniye Mosque
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.020203, 28.965454, Distance=0.45 km, GEOHASH: sxk975
# Nearest Coordinate 2: 41.009216, 28.965454, Distance=0.80 km, GEOHASH: sxk971
#
# Nearest Coordinates to Taksim Square - Istanbul
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.036682, 28.987427, Distance=0.22 km, GEOHASH: sxk97w
# Nearest Coordinate 2: 41.042175, 28.987427, Distance=0.48 km, GEOHASH: sxk97x
# Nearest Coordinate 3: 41.03119, 28.987427, Distance=0.78 km, GEOHASH: sxk97t
#
# Nearest Coordinates to Topkapı Palace
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 28.987427, Distance=0.34 km, GEOHASH: sxk97d
# Nearest Coordinate 2: 41.009216, 28.987427, Distance=0.50 km, GEOHASH: sxk979
# Nearest Coordinate 3: 41.01471, 28.97644, Distance=0.67 km, GEOHASH: sxk976
#
# Nearest Coordinates to Valens Su Kemeri
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 28.954468, Distance=0.18 km, GEOHASH: sxk96f
# Nearest Coordinate 2: 41.020203, 28.954468, Distance=0.44 km, GEOHASH: sxk96g
# Nearest Coordinate 3: 41.009216, 28.954468, Distance=0.79 km, GEOHASH: sxk96c
#
# Nearest Coordinates to Yavuz Sultan Selim Bridge
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.201477, 29.119263, Distance=0.20 km, GEOHASH: sxkdqs
# Nearest Coordinate 2: 41.195984, 29.119263, Distance=0.42 km, GEOHASH: sxkdqe
#
# Nearest Coordinates to Yıldız Park - Beşiktaş
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.04767, 29.020386, Distance=0.40 km, GEOHASH: sxk9s2
# Nearest Coordinate 2: 41.04767, 29.0094, Distance=0.53 km, GEOHASH: sxk9s0
# Nearest Coordinate 3: 41.05316, 29.020386, Distance=0.71 km, GEOHASH: sxk9s3
# Nearest Coordinate 4: 41.05316, 29.0094, Distance=0.79 km, GEOHASH: sxk9s1
# Nearest Coordinate 5: 41.042175, 29.0094, Distance=0.82 km, GEOHASH: sxk9kp
#
# Nearest Coordinates to Çamlıca Kulesi - Istanbul
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 29.064331, Distance=0.21 km, GEOHASH: sxk9m6
# Nearest Coordinate 2: 41.020203, 29.064331, Distance=0.44 km, GEOHASH: sxk9m7
# Nearest Coordinate 3: 41.009216, 29.064331, Distance=0.80 km, GEOHASH: sxk9m3
#
# Nearest Coordinates to Çırağan Palace
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 29.0094, Distance=0.52 km, GEOHASH: sxk9kp
# Nearest Coordinate 2: 41.04767, 29.020386, Distance=0.63 km, GEOHASH: sxk9s2
# Nearest Coordinate 3: 41.04767, 29.0094, Distance=0.68 km, GEOHASH: sxk9s0
#
# Nearest Coordinates to İBB 15 Temmuz Şehitler Ormanı ve Anıtı
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.20697, 29.09729, Distance=0.14 km, GEOHASH: sxkdqj
# Nearest Coordinate 2: 41.212463, 29.09729, Distance=0.56 km, GEOHASH: sxkdqn
#
# Nearest Coordinates to İstanbul Arkeoloji Müzeleri
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.01471, 28.97644, Distance=0.53 km, GEOHASH: sxk976
# Nearest Coordinate 2: 41.009216, 28.987427, Distance=0.58 km, GEOHASH: sxk979
# Nearest Coordinate 3: 41.01471, 28.987427, Distance=0.61 km, GEOHASH: sxk97d
#
# Nearest Coordinates to İstanbul Atatürk Havalimanı
# ---------------------------------------------------------
# Nearest Coordinate 1: 40.98175, 28.822632, Distance=0.53 km, GEOHASH: sxk3pu
# Nearest Coordinate 2: 40.976257, 28.833618, Distance=0.70 km, GEOHASH: sxk905
#
# Nearest Coordinates to İstanbul Havalimanı
# ---------------------------------------------------------
#
# Nearest Coordinates to İstanbul Modern Museum
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.025696, 28.987427, Distance=0.39 km, GEOHASH: sxk97s
# Nearest Coordinate 2: 41.025696, 28.97644, Distance=0.54 km, GEOHASH: sxk97k
# Nearest Coordinate 3: 41.03119, 28.987427, Distance=0.70 km, GEOHASH: sxk97t
# Nearest Coordinate 4: 41.03119, 28.97644, Distance=0.79 km, GEOHASH: sxk97m
# Nearest Coordinate 5: 41.020203, 28.97644, Distance=0.83 km, GEOHASH: sxk977
#
# Nearest Coordinates to İstiklal Caddesi
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.97644, Distance=0.34 km, GEOHASH: sxk97m
# Nearest Coordinate 2: 41.036682, 28.97644, Distance=0.35 km, GEOHASH: sxk97q
# Nearest Coordinate 3: 41.025696, 28.97644, Distance=0.92 km, GEOHASH: sxk97k
# Nearest Coordinate 4: 41.042175, 28.97644, Distance=0.93 km, GEOHASH: sxk97r
#
# Wall time: 170 ms

# %%
df = (
    pd.concat([pd.DataFrame(new_list), pd.DataFrame(hist_list)], ignore_index=True)
    .drop_duplicates()
)

# %%
df
# Out:
#          type                                    name   latitude  longitude
# 0     geohash                                  sxk9kz  41.042175  29.042358  \
# 1     geohash                                  sxk9ky  41.036682  29.042358
# 2     geohash                                  sxk9kv  41.031190  29.042358
# 3     geohash                                  sxk97k  41.025696  28.976440
# 4     geohash                                  sxk97m  41.031190  28.976440
# ..        ...                                     ...        ...        ...
# 262  landmark  İBB 15 Temmuz Şehitler Ormanı ve Anıtı  41.207560  29.095861
# 264  landmark             İstanbul Arkeoloji Müzeleri  41.011699  28.981323
# 267  landmark             İstanbul Atatürk Havalimanı  40.977497  28.825494
# 269  landmark                  İstanbul Modern Museum  41.025911  28.982812
# 274  landmark                        İstiklal Caddesi  41.033893  28.978248
#
#                                     nearest
# 0                 5 Temmuz Şehitler Köprüsü
# 1                 5 Temmuz Şehitler Köprüsü
# 2                 5 Temmuz Şehitler Köprüsü
# 3     500. Yıl Vakfı Türk Musevileri Müzesi
# 4     500. Yıl Vakfı Türk Musevileri Müzesi
# ..                                      ...
# 262  İBB 15 Temmuz Şehitler Ormanı ve Anıtı
# 264             İstanbul Arkeoloji Müzeleri
# 267             İstanbul Atatürk Havalimanı
# 269                  İstanbul Modern Museum
# 274                        İstiklal Caddesi
#
# [180 rows x 5 columns]

# %%
# some GEOHASH has around 8 landmarks within its 1km radius
(
    df.query("type=='geohash'")
    .groupby('name')
    .size()
    .nlargest(3)
)
# Out:
# name
# sxk976    8
# sxk97k    8
# sxk977    7
# dtype: int64

# %%
df.query("name=='sxk976'")
# Out:
#         type    name  latitude  longitude                           nearest
# 13   geohash  sxk976  41.01471   28.97644                  Basilica Cistern
# 25   geohash  sxk976  41.01471   28.97644             Egyptian Spice Bazaar
# 35   geohash  sxk976  41.01471   28.97644                     Galata Bridge
# 46   geohash  sxk976  41.01471   28.97644                     Gülhane Parkı
# 52   geohash  sxk976  41.01471   28.97644                      Hagia Sophia
# 79   geohash  sxk976  41.01471   28.97644  Museum of Turkish & Islamic Arts
# 106  geohash  sxk976  41.01471   28.97644                    Topkapı Palace
# 125  geohash  sxk976  41.01471   28.97644       İstanbul Arkeoloji Müzeleri

# %%
df
# Out:
#          type                                    name   latitude  longitude
# 0     geohash                                  sxk9kz  41.042175  29.042358  \
# 1     geohash                                  sxk9ky  41.036682  29.042358
# 2     geohash                                  sxk9kv  41.031190  29.042358
# 3     geohash                                  sxk97k  41.025696  28.976440
# 4     geohash                                  sxk97m  41.031190  28.976440
# ..        ...                                     ...        ...        ...
# 262  landmark  İBB 15 Temmuz Şehitler Ormanı ve Anıtı  41.207560  29.095861
# 264  landmark             İstanbul Arkeoloji Müzeleri  41.011699  28.981323
# 267  landmark             İstanbul Atatürk Havalimanı  40.977497  28.825494
# 269  landmark                  İstanbul Modern Museum  41.025911  28.982812
# 274  landmark                        İstiklal Caddesi  41.033893  28.978248
#
#                                     nearest
# 0                 5 Temmuz Şehitler Köprüsü
# 1                 5 Temmuz Şehitler Köprüsü
# 2                 5 Temmuz Şehitler Köprüsü
# 3     500. Yıl Vakfı Türk Musevileri Müzesi
# 4     500. Yıl Vakfı Türk Musevileri Müzesi
# ..                                      ...
# 262  İBB 15 Temmuz Şehitler Ormanı ve Anıtı
# 264             İstanbul Arkeoloji Müzeleri
# 267             İstanbul Atatürk Havalimanı
# 269                  İstanbul Modern Museum
# 274                        İstiklal Caddesi
#
# [180 rows x 5 columns]

# %%
df.to_csv("datasets/13_gh_proximities/gh_nearby_landmarks.csv", index=False)
