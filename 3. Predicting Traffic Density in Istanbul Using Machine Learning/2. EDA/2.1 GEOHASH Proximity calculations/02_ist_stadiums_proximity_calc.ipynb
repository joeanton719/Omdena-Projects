# %%
from scipy.spatial import KDTree
from geopy.distance import geodesic
import pandas as pd

# %%
gh_df = (
    pd.read_csv("geohash_traffic_density_pt_15clusters.csv", usecols=['GEOHASH', 'LATITUDE', 'LONGITUDE'])
)

# Reading Football match dataset and converting to list
# Each key is a stadium and the values are its coordinates
site_dict = (
    pd.read_csv("datasets/05_tr_football_matches/tr_ist_2019_2023_football_matches.csv", usecols=['stadium', 'stad_lat', 'stad_long'])
    .drop_duplicates(ignore_index=True)
    .set_index('stadium')
    .T
    .to_dict()
)

# %%
# Unique list of coordinates
coordinates = gh_df[['LATITUDE', 'LONGITUDE']].drop_duplicates().values
coordinates
# Out:
# array([[41.080627, 28.811646],
#        [40.987244, 29.108276],
#        [41.003723, 29.09729 ],
#        ...,
#        [40.976257, 29.229126],
#        [41.009216, 27.98767 ],
#        [41.020203, 27.998657]])

# %%
def find_nearest_coordinates(
        target_lat: float,
        target_lon: float,
        coordinates: list[list[float, float]]
        ) -> list[tuple[tuple[float, float], float]]:
    """
    Finds the nearest coordinates to a target latitude and longitude.

    Args:
        target_lat (float): The latitude of the target location.
        target_lon (float): The longitude of the target location.
        coordinates (List[Tuple[float, float]]): A list of tuples representing the coordinates to search from.

    Returns:
        List[Tuple[Tuple[float, float], float]]: A list of tuples containing the nearest coordinates and their distances in kilometers.
    """
    target_coords = (target_lat, target_lon)
    
    # Build a KDTree for efficient nearest neighbor search
    tree = KDTree(coordinates)

    # Calculate the search radius in degrees
    radius_deg = 1 / 111.0  # 1 km radius in degrees

    # Query the KDTree for indices of points within the search radius
    indices = tree.query_ball_point([(target_lat, target_lon)], radius_deg)

    # Calculate the distance between target coordinates and nearest coordinates
    nearest_coordinates = [(coordinates[i], geodesic(target_coords, coordinates[i]).km) for i in indices[0]]

    # Sort the nearest coordinates by distance
    nearest_coordinates.sort(key=lambda x: x[1])  # Sort by distance

    return nearest_coordinates

# %%
stad_list = []
new_list = []

for site in site_dict:

    target_lat = site_dict[site]['stad_lat']
    target_lon = site_dict[site]['stad_long']

    nearest_coords = find_nearest_coordinates(target_lat, target_lon, coordinates)

    print(f"Nearest Coordinates to {site}")
    print("---------------------------------------------------------")

    for i, (coords, distance) in enumerate(nearest_coords):

        gh = gh_df.loc[gh_df['LATITUDE'].eq(coords[0]) & gh_df['LONGITUDE'].eq(coords[1]), 'GEOHASH'].values[0]
        print(f"Nearest Coordinate {i+1}: {coords[0]}, {coords[1]}, Distance={distance:.2f} km, GEOHASH: {gh}")

        # Creating two dataframe which will later be merged rows wise for visualization purpose.
        stad_list.append({
            "type" : "stadium",
            "name" : site,
            "latitude" : target_lat,
            "longitude" : target_lon,
            "nearest" : site
        })

        new_list.append({
            "type" : "geohash",
            "name" : gh,
            "latitude" : coords[0],
            "longitude" : coords[1],
            "nearest" : site
        })

    print()
# Out:
# Nearest Coordinates to BAŞAKŞEHİR FATİH TERİM
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.124573, 28.811646, Distance=0.27 km, GEOHASH: sxk3zw
# Nearest Coordinate 2: 41.11908, 28.811646, Distance=0.46 km, GEOHASH: sxk3zt
# Nearest Coordinate 3: 41.130066, 28.811646, Distance=0.83 km, GEOHASH: sxk3zx
#
# Nearest Coordinates to RECEP TAYYİP ERDOĞAN STADYUMU
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.03119, 28.97644, Distance=0.38 km, GEOHASH: sxk97m
# Nearest Coordinate 2: 41.036682, 28.97644, Distance=0.56 km, GEOHASH: sxk97q
# Nearest Coordinate 3: 41.03119, 28.965454, Distance=0.61 km, GEOHASH: sxk97j
# Nearest Coordinate 4: 41.036682, 28.965454, Distance=0.73 km, GEOHASH: sxk97n
# Nearest Coordinate 5: 41.025696, 28.97644, Distance=0.85 km, GEOHASH: sxk97k
#
# Nearest Coordinates to ÜLKER STADYUMU
# ---------------------------------------------------------
# Nearest Coordinate 1: 40.987244, 29.042358, Distance=0.46 km, GEOHASH: sxk9hv
# Nearest Coordinate 2: 40.987244, 29.031372, Distance=0.47 km, GEOHASH: sxk9ht
# Nearest Coordinate 3: 40.992737, 29.042358, Distance=0.73 km, GEOHASH: sxk9hy
# Nearest Coordinate 4: 40.992737, 29.031372, Distance=0.74 km, GEOHASH: sxk9hw
# Nearest Coordinate 5: 40.98175, 29.042358, Distance=0.80 km, GEOHASH: sxk9hu
#
# Nearest Coordinates to VODAFONE PARK
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.042175, 28.998413, Distance=0.45 km, GEOHASH: sxk97z
# Nearest Coordinate 2: 41.036682, 28.998413, Distance=0.46 km, GEOHASH: sxk97y
# Nearest Coordinate 3: 41.042175, 28.987427, Distance=0.66 km, GEOHASH: sxk97x
# Nearest Coordinate 4: 41.036682, 28.987427, Distance=0.66 km, GEOHASH: sxk97w
#
# Nearest Coordinates to NEF STADYUMU
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.1026, 28.987427, Distance=0.32 km, GEOHASH: sxk9gd
# Nearest Coordinate 2: 41.108093, 28.987427, Distance=0.60 km, GEOHASH: sxk9ge
# Nearest Coordinate 3: 41.1026, 28.998413, Distance=0.63 km, GEOHASH: sxk9gf
# Nearest Coordinate 4: 41.097107, 28.987427, Distance=0.76 km, GEOHASH: sxk9g9
# Nearest Coordinate 5: 41.108093, 28.998413, Distance=0.81 km, GEOHASH: sxk9gg
#
# Nearest Coordinates to ATATÜRK OLİMPİYAT
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.075134, 28.7677, Distance=0.19 km, GEOHASH: sxk3wt
# Nearest Coordinate 2: 41.06964, 28.7677, Distance=0.56 km, GEOHASH: sxk3ws
# Nearest Coordinate 3: 41.080627, 28.7677, Distance=0.70 km, GEOHASH: sxk3ww
#
# Nearest Coordinates to NECMİ KADIOĞLU
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.025696, 28.690796, Distance=0.61 km, GEOHASH: sxk3ku
# Nearest Coordinate 2: 41.020203, 28.690796, Distance=0.75 km, GEOHASH: sxk3kg
#
# Nearest Coordinates to ÜMRANİYE STADYUMU
# ---------------------------------------------------------
# Nearest Coordinate 1: 41.058655, 29.108276, Distance=0.10 km, GEOHASH: sxk9w6
# Nearest Coordinate 2: 41.064148, 29.108276, Distance=0.61 km, GEOHASH: sxk9w7

# %%
df = (
    pd.concat([pd.DataFrame(new_list), pd.DataFrame(stad_list)], ignore_index=True)
    .drop_duplicates()
)

df
# Out:
#        type                           name   latitude  longitude
# 0   geohash                         sxk3zw  41.124573  28.811646  \
# 1   geohash                         sxk3zt  41.119080  28.811646
# 2   geohash                         sxk3zx  41.130066  28.811646
# 3   geohash                         sxk97m  41.031190  28.976440
# 4   geohash                         sxk97q  41.036682  28.976440
# 5   geohash                         sxk97j  41.031190  28.965454
# 6   geohash                         sxk97n  41.036682  28.965454
# 7   geohash                         sxk97k  41.025696  28.976440
# 8   geohash                         sxk9hv  40.987244  29.042358
# 9   geohash                         sxk9ht  40.987244  29.031372
# 10  geohash                         sxk9hy  40.992737  29.042358
# 11  geohash                         sxk9hw  40.992737  29.031372
# 12  geohash                         sxk9hu  40.981750  29.042358
# 13  geohash                         sxk97z  41.042175  28.998413
# 14  geohash                         sxk97y  41.036682  28.998413
# 15  geohash                         sxk97x  41.042175  28.987427
# 16  geohash                         sxk97w  41.036682  28.987427
# 17  geohash                         sxk9gd  41.102600  28.987427
# 18  geohash                         sxk9ge  41.108093  28.987427
# 19  geohash                         sxk9gf  41.102600  28.998413
# 20  geohash                         sxk9g9  41.097107  28.987427
# 21  geohash                         sxk9gg  41.108093  28.998413
# 22  geohash                         sxk3wt  41.075134  28.767700
# 23  geohash                         sxk3ws  41.069640  28.767700
# 24  geohash                         sxk3ww  41.080627  28.767700
# 25  geohash                         sxk3ku  41.025696  28.690796
# 26  geohash                         sxk3kg  41.020203  28.690796
# 27  geohash                         sxk9w6  41.058655  29.108276
# 28  geohash                         sxk9w7  41.064148  29.108276
# 29  stadium         BAŞAKŞEHİR FATİH TERİM  41.122807  28.809385
# 32  stadium  RECEP TAYYİP ERDOĞAN STADYUMU  41.032745  28.972365
# 37  stadium                 ÜLKER STADYUMU  40.987636  29.036942
# 42  stadium                  VODAFONE PARK  41.039444  28.994412
# 46  stadium                   NEF STADYUMU  41.103426  28.991038
# 51  stadium              ATATÜRK OLİMPİYAT  41.074473  28.765661
# 54  stadium                NECMİ KADIOĞLU  41.024317  28.697846
# 56  stadium              ÜMRANİYE STADYUMU  41.058762  29.109409
#
#                           nearest
# 0          BAŞAKŞEHİR FATİH TERİM
# 1          BAŞAKŞEHİR FATİH TERİM
# 2          BAŞAKŞEHİR FATİH TERİM
# 3   RECEP TAYYİP ERDOĞAN STADYUMU
# 4   RECEP TAYYİP ERDOĞAN STADYUMU
# 5   RECEP TAYYİP ERDOĞAN STADYUMU
# 6   RECEP TAYYİP ERDOĞAN STADYUMU
# 7   RECEP TAYYİP ERDOĞAN STADYUMU
# 8                  ÜLKER STADYUMU
# 9                  ÜLKER STADYUMU
# 10                 ÜLKER STADYUMU
# 11                 ÜLKER STADYUMU
# 12                 ÜLKER STADYUMU
# 13                  VODAFONE PARK
# 14                  VODAFONE PARK
# 15                  VODAFONE PARK
# 16                  VODAFONE PARK
# 17                   NEF STADYUMU
# 18                   NEF STADYUMU
# 19                   NEF STADYUMU
# 20                   NEF STADYUMU
# 21                   NEF STADYUMU
# 22              ATATÜRK OLİMPİYAT
# 23              ATATÜRK OLİMPİYAT
# 24              ATATÜRK OLİMPİYAT
# 25                NECMİ KADIOĞLU
# 26                NECMİ KADIOĞLU
# 27              ÜMRANİYE STADYUMU
# 28              ÜMRANİYE STADYUMU
# 29         BAŞAKŞEHİR FATİH TERİM
# 32  RECEP TAYYİP ERDOĞAN STADYUMU
# 37                 ÜLKER STADYUMU
# 42                  VODAFONE PARK
# 46                   NEF STADYUMU
# 51              ATATÜRK OLİMPİYAT
# 54                NECMİ KADIOĞLU
# 56              ÜMRANİYE STADYUMU

# %%
# All GEOHASH in this list has only 1 stadium within its 1km radius
(
    df.query("type=='geohash'")
    .groupby('name')['nearest'].nunique()
    .nlargest(5)
)
# Out:
# name
# sxk3kg    1
# sxk3ku    1
# sxk3ws    1
# sxk3wt    1
# sxk3ww    1
# Name: nearest, dtype: int64

# %%
df.to_csv("datasets/13_gh_proximities/gh_nearby_stadiums.csv", index=False)
